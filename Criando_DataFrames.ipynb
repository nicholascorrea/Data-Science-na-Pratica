# %% [markdown]
# <a href="https://colab.research.google.com/github/nicholascorrea/Data-Science-na-Pratica/blob/main/Criando_DataFrames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Criando DataFrames

# %% [markdown]
# ## DataFrames a partir de dicionários
# Uma das estruturas básicas do Python é o Dicionário. É muito conveniente informarmos nossos dados em uma variável do tipo `dict`, pois sua conversão em *DataFrame* é muito simples e direta.

# %%
# importando o pandas
import pandas as pd

# %%
# criar dicionário
dados = {
    'nome': ['Nicholas', 'Vitória', 'João', 'Erika'],
    'idade': [39, 9, 17, 40],
    'cidade': ['São Paulo', 'Mogi das Cruzes', 'Rio de Janeiro', 'Curitiba'],
    'comprou': [True, False, False, True]
}

# %%
#criar DataFrame
df = pd.DataFrame(dados)

# %%
#visualizar DataFrame
df
# Out:
#        nome  idade           cidade  comprou
# 0  Nicholas     39        São Paulo     True
# 1   Vitória      9  Mogi das Cruzes    False
# 2      João     17   Rio de Janeiro    False
# 3     Erika     40         Curitiba     True

# %% [markdown]
# Após criar o DataFrame, podemos adicionar elementos a ele.
# Por exemplo, adicionar uma lista de id de usuários ao DataFrame como no exemplo abaixo.

# %%
# criar id do usuario
id_usuario = [12, 20, 55, 15]

# %%
# associar id do usuário a lista
df.index = id_usuario
